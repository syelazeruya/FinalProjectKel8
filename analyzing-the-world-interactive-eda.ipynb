# %%
# Copied this code cell from https://www.kaggle.com/code/shtrausslearning/bayesian-regression-house-price-prediction
from IPython.core.display import display, HTML, Javascript

color_map = ['#FFFFFF','#FF5733']

prompt = color_map[-1]
main_color = color_map[0]
strong_main_color = color_map[1]
custom_colors = [strong_main_color, main_color]

css_file = '''
div #notebook {
background-color: white;
line-height: 20px;
}

#notebook-container {
# %s
margin-top: 2em;
padding-top: 2em;
border-top: 4px solid %s;
-webkit-box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
    box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
}

div .input {
margin-bottom: 1em;
}

.rendered_html h1, .rendered_html h2, .rendered_html h3, .rendered_html h4, .rendered_html h5, .rendered_html h6 {
color: %s;
font-weight: 600;
}

div.input_area {
border: none;
    background-color: %s;
    border-top: 2px solid %s;
}

div.input_prompt {
color: %s;
}

div.output_prompt {
color: %s; 
}

div.cell.selected:before, div.cell.selected.jupyter-soft-selected:before {
background: %s;
}

div.cell.selected, div.cell.selected.jupyter-soft-selected {
    border-color: %s;
}

.edit_mode div.cell.selected:before {
background: %s;
}

.edit_mode div.cell.selected {
border-color: %s;

}
'''

def to_rgb(h): 
    return tuple(int(h[i:i+2], 16) for i in [0, 2, 4])

main_color_rgba = 'rgba(%s, %s, %s, 0.1)' % (to_rgb(main_color[1:]))
open('notebook.css', 'w').write(css_file % ('width: 95%;', main_color, main_color, main_color_rgba, 
                                            main_color,  main_color, prompt, main_color, main_color, 
                                            main_color, main_color))

def nb(): 
    return HTML("<style>" + open("notebook.css", "r").read() + "</style>")
nb()
# Out:
# /tmp/ipykernel_20/223129880.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, Javascript
# <style>
# div #notebook {
# background-color: white;
# line-height: 20px;
# }
#
# #notebook-container {
# width: 95%;
# margin-top: 2em;
# padding-top: 2em;
# border-top: 4px solid #FFFFFF;
# -webkit-box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
#     box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
# }
#
# div .input {
# margin-bottom: 1em;
# }
#
# .rendered_html h1, .rendered_html h2, .rendered_html h3, .rendered_html h4, .rendered_html h5, .rendered_html h6 {
# color: #FFFFFF;
# font-weight: 600;
# }
#
# div.input_area {
# border: none;
#     background-color: rgba(255, 255, 255, 0.1);
#     border-top: 2px solid #FFFFFF;
# }
#
# div.input_prompt {
# color: #FFFFFF;
# }
#
# div.output_prompt {
# color: #FF5733;
# }
#
# div.cell.selected:before, div.cell.selected.jupyter-soft-selected:before {
# background: #FFFFFF;
# }
#
# div.cell.selected, div.cell.selected.jupyter-soft-selected {
#     border-color: #FFFFFF;
# }
#
# .edit_mode div.cell.selected:before {
# background: #FFFFFF;
# }
#
# .edit_mode div.cell.selected {
# border-color: #FFFFFF;
#
# }
# </style>

# %% [markdown]
# <font size="+3" color="#000000"><b>1 <span style='color:#4285f4; font-weight:bold'>|</span> Importing Libraries </b></font><br><a id="1"></a>
# - **For Data Processing**: sqlite3, numpy, pandas
# - **For Data Visualization**: matplotlib, seaborn, plotly

# %%
import numpy as np
import pandas as pd
import sqlite3
import math
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Hide Warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# <font size="+3" color="#000000"><b>2 <span style='color:#4285f4; font-weight:bold'>|</span> Reading the Dataset </b></font><br><a id="1"></a>

# %%
conn = sqlite3.connect('/kaggle/input/world-data/world.sqlite')
df = pd.read_sql_query("SELECT * FROM world", conn)
df = pd.DataFrame(df)
numeric_columns = [
    'Density','ArmedForcesSize','CallingCode','Co2-Emissions',
 'Population','MinimumWage','LandArea','MaternalMortalityRatio',
 'LifeExpectancy','UnemploymentRate','Urban_population','Longitude',
 'AgriculturalLand','BirthRate','ForestedArea','CPI','CPIChange',
 'FertilityRate','GrossPrimaryEducationEnrollment','Latitude',
 'GrossTertiaryEducationEnrollment','GDP','GasolinePrice',
 'PopulationLaborForceParticipation','TaxRevenue','TotalTaxRate',
 'InfantMortality','OutOfPocketHealthExpenditure','PhysiciansPerThousand',
]
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric)

# %%
display(df.head(6).T)
print(f'shape: {df.shape[0]} rows by {df.shape[1]} columns')
# Out:
#                                              0            1             2  \
# Country                            Afghanistan      Albania       Algeria
# Density                                     60          105            18
# Abbreviation                                AF           AL            DZ
# AgriculturalLand                          58.1         43.1          17.4
# LandArea                                652230        28748       2381741
# ArmedForcesSize                         323000         9000        317000
# BirthRate                                32.49        11.78         24.28
# CallingCode                                 93          355           213
# Capital                                  Kabul       Tirana       Algiers
# Co2-Emissions                             8672         4536        150006
# CPI                                      149.9       119.05        151.36
# CPIChange                                  2.3          1.4           2.0
# Currency-Code                              AFN          ALL           DZD
# FertilityRate                             4.47         1.62          3.02
# ForestedArea                               2.1         28.1           0.8
# GasolinePrice                              0.7         1.36          0.28
# GDP                                19101353833  15278077447  169988236398
# GrossPrimaryEducationEnrollment          104.0        107.0         109.9
# GrossTertiaryEducationEnrollment           9.7         55.0          51.4
# InfantMortality                           47.9          7.8          20.1
# LargestCity                              Kabul       Tirana       Algiers
# LifeExpectancy                            64.5         78.5          76.7
# MaternalMortalityRatio                     638           15           112
# MinimumWage                               0.43         1.12          0.95
# OfficialLanguage                        Pashto     Albanian        Arabic
# OutOfPocketHealthExpenditure              78.4         56.9          28.1
# PhysiciansPerThousand                     0.28          1.2          1.72
# Population                            38041754      2854191      43053054
# PopulationLaborForceParticipation         48.9         55.7          41.2
# TaxRevenue                                 9.3         18.6          37.2
# TotalTaxRate                              71.4         36.6          66.1
# UnemploymentRate                         11.12        12.33          11.7
# Urban_population                       9797273      1747593      31510100
# Latitude                              33.93911    41.153332     28.033886
# Longitude                            67.709953    20.168331      1.659626
#
#                                              3             4            5
# Country                                 Angola     Argentina      Armenia
# Density                                     26            17          104
# Abbreviation                                AO            AR           AM
# AgriculturalLand                          47.5          54.3         58.9
# LandArea                               1246700       2780400        29743
# ArmedForcesSize                         117000        105000        49000
# BirthRate                                40.73         17.02        13.99
# CallingCode                                244            54          374
# Capital                                 Luanda  Buenos Aires      Yerevan
# Co2-Emissions                            34693        201348         5156
# CPI                                     261.73        232.75       129.18
# CPIChange                                 17.1          53.5          1.4
# Currency-Code                              AOA           ARS          AMD
# FertilityRate                             5.52          2.26         1.76
# ForestedArea                              46.3           9.8         11.7
# GasolinePrice                             0.97           1.1         0.77
# GDP                                94635415870  449663446954  13672802158
# GrossPrimaryEducationEnrollment          113.5         109.7         92.7
# GrossTertiaryEducationEnrollment           9.3          90.0         54.6
# InfantMortality                           51.6           8.8         11.0
# LargestCity                             Luanda  Buenos Aires      Yerevan
# LifeExpectancy                            60.8          76.5         74.9
# MaternalMortalityRatio                     241            39           26
# MinimumWage                               0.71          3.35         0.66
# OfficialLanguage                    Portuguese       Spanish     Armenian
# OutOfPocketHealthExpenditure              33.4          17.6         81.6
# PhysiciansPerThousand                     0.21          3.96          4.4
# Population                            31825295      44938712      2957731
# PopulationLaborForceParticipation         77.5          61.3         55.6
# TaxRevenue                                 9.2          10.1         20.9
# TotalTaxRate                              49.1         106.3         22.6
# UnemploymentRate                          6.89          9.79        16.99
# Urban_population                      21061025      41339571      1869848
# Latitude                            -11.202692    -38.416097    40.069099
# Longitude                            17.873887    -63.616672    45.038189
# shape: 107 rows by 35 columns

# %% [markdown]
# GDP per Capita can be incredibly useful to find patterns and draw insights from data, so I'm creating a new column for the GDP per Capita for each country.
# If you don't know what this is, here's a simple explaination I found on the internet:
# **GDP per Capita:** This is the total income of a country, divided by the number of people living in that country. GDP per capita shows how much money people make on an average by working in that country.

# %%
df['GDP_per_Capita'] = df['GDP'] / df['Population']

# %% [markdown]
# <font size="+2" color="#000000"><b style="font-weight:normal">2.1 <span style='color:#4285f4; font-weight:normal'>|</span> Dataset Statistics </b></font><br><a id="1"></a>

# %%
df.describe()[1:].T.style.background_gradient(cmap='Blues', axis=1)
# Out:
# <style type="text/css">
# #T_3e4a8_row0_col0, #T_3e4a8_row0_col5, #T_3e4a8_row14_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_3e4a8_row0_col1, #T_3e4a8_row18_col0, #T_3e4a8_row25_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_3e4a8_row0_col2, #T_3e4a8_row1_col2, #T_3e4a8_row2_col2, #T_3e4a8_row2_col3, #T_3e4a8_row3_col2, #T_3e4a8_row3_col3, #T_3e4a8_row4_col2, #T_3e4a8_row5_col2, #T_3e4a8_row6_col2, #T_3e4a8_row6_col3, #T_3e4a8_row6_col4, #T_3e4a8_row7_col2, #T_3e4a8_row8_col2, #T_3e4a8_row9_col2, #T_3e4a8_row10_col2, #T_3e4a8_row11_col2, #T_3e4a8_row12_col2, #T_3e4a8_row12_col3, #T_3e4a8_row12_col4, #T_3e4a8_row13_col1, #T_3e4a8_row14_col2, #T_3e4a8_row15_col2, #T_3e4a8_row16_col1, #T_3e4a8_row17_col2, #T_3e4a8_row18_col2, #T_3e4a8_row19_col2, #T_3e4a8_row20_col2, #T_3e4a8_row21_col2, #T_3e4a8_row21_col3, #T_3e4a8_row22_col1, #T_3e4a8_row23_col2, #T_3e4a8_row24_col2, #T_3e4a8_row25_col2, #T_3e4a8_row26_col2, #T_3e4a8_row26_col3, #T_3e4a8_row27_col2, #T_3e4a8_row28_col2, #T_3e4a8_row29_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3e4a8_row0_col3, #T_3e4a8_row7_col4, #T_3e4a8_row12_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_3e4a8_row0_col4 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_3e4a8_row0_col6, #T_3e4a8_row1_col6, #T_3e4a8_row2_col6, #T_3e4a8_row3_col6, #T_3e4a8_row4_col6, #T_3e4a8_row5_col6, #T_3e4a8_row6_col6, #T_3e4a8_row7_col6, #T_3e4a8_row8_col6, #T_3e4a8_row9_col6, #T_3e4a8_row10_col6, #T_3e4a8_row11_col6, #T_3e4a8_row12_col6, #T_3e4a8_row13_col6, #T_3e4a8_row14_col6, #T_3e4a8_row15_col6, #T_3e4a8_row16_col6, #T_3e4a8_row17_col6, #T_3e4a8_row18_col6, #T_3e4a8_row19_col6, #T_3e4a8_row20_col6, #T_3e4a8_row21_col6, #T_3e4a8_row22_col6, #T_3e4a8_row23_col6, #T_3e4a8_row24_col6, #T_3e4a8_row25_col6, #T_3e4a8_row26_col6, #T_3e4a8_row27_col6, #T_3e4a8_row28_col6, #T_3e4a8_row29_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3e4a8_row1_col0 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_3e4a8_row1_col1, #T_3e4a8_row8_col1, #T_3e4a8_row18_col1, #T_3e4a8_row19_col3 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_3e4a8_row1_col3 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_3e4a8_row1_col4 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_3e4a8_row1_col5, #T_3e4a8_row22_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_3e4a8_row2_col0, #T_3e4a8_row7_col5 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_3e4a8_row2_col1, #T_3e4a8_row5_col4, #T_3e4a8_row29_col5 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_3e4a8_row2_col4, #T_3e4a8_row3_col4, #T_3e4a8_row12_col5, #T_3e4a8_row17_col3, #T_3e4a8_row29_col3 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_3e4a8_row2_col5, #T_3e4a8_row17_col4, #T_3e4a8_row26_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_3e4a8_row3_col0, #T_3e4a8_row3_col5 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_3e4a8_row3_col1, #T_3e4a8_row8_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_3e4a8_row4_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_3e4a8_row4_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_3e4a8_row4_col3, #T_3e4a8_row9_col3 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_3e4a8_row4_col4, #T_3e4a8_row9_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_3e4a8_row4_col5 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_3e4a8_row5_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_3e4a8_row5_col1, #T_3e4a8_row17_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_3e4a8_row5_col3, #T_3e4a8_row7_col0, #T_3e4a8_row11_col1, #T_3e4a8_row24_col1, #T_3e4a8_row29_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_3e4a8_row5_col5 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_3e4a8_row6_col0, #T_3e4a8_row7_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_3e4a8_row6_col1, #T_3e4a8_row12_col1, #T_3e4a8_row29_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_3e4a8_row6_col5, #T_3e4a8_row7_col3, #T_3e4a8_row21_col4, #T_3e4a8_row26_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_3e4a8_row8_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_3e4a8_row8_col4 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_3e4a8_row8_col5, #T_3e4a8_row29_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_3e4a8_row9_col1, #T_3e4a8_row15_col3, #T_3e4a8_row20_col3 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_3e4a8_row9_col4 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_3e4a8_row9_col5 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_3e4a8_row10_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_3e4a8_row10_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_3e4a8_row10_col3 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_3e4a8_row10_col4 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_3e4a8_row10_col5 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_3e4a8_row11_col0, #T_3e4a8_row11_col4 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_3e4a8_row11_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_3e4a8_row11_col5 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_3e4a8_row13_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_3e4a8_row13_col2 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_3e4a8_row13_col3 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_3e4a8_row13_col4 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_3e4a8_row13_col5 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_3e4a8_row14_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_3e4a8_row14_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_3e4a8_row14_col4, #T_3e4a8_row25_col4 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_3e4a8_row14_col5 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_3e4a8_row15_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_3e4a8_row15_col1, #T_3e4a8_row24_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_3e4a8_row15_col4, #T_3e4a8_row17_col5 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_3e4a8_row15_col5, #T_3e4a8_row19_col0, #T_3e4a8_row24_col5 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_3e4a8_row16_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_3e4a8_row16_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_3e4a8_row16_col3, #T_3e4a8_row27_col5 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_3e4a8_row16_col4 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_3e4a8_row16_col5 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_3e4a8_row17_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_3e4a8_row18_col3, #T_3e4a8_row21_col5, #T_3e4a8_row26_col5 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_3e4a8_row18_col4 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_3e4a8_row18_col5 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_3e4a8_row19_col1, #T_3e4a8_row23_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_3e4a8_row19_col4, #T_3e4a8_row23_col4 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_3e4a8_row19_col5 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_3e4a8_row20_col0 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_3e4a8_row20_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_3e4a8_row20_col4 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_3e4a8_row20_col5, #T_3e4a8_row23_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_3e4a8_row21_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_3e4a8_row21_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_3e4a8_row22_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_3e4a8_row22_col3 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_3e4a8_row22_col4 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_3e4a8_row22_col5 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_3e4a8_row23_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_3e4a8_row23_col5 {

# %% [markdown]
# <font size="+2" color="#000000"><b style="font-weight:normal">2.2 <span style='color:#4285f4; font-weight:normal'>|</span> Correlation Matrix </b></font><br><a id="1"></a>

# %%
fig = px.imshow(df[numeric_columns+["GDP_per_Capita"]].corr(),color_continuous_scale="Blues")
fig.update_layout(height=1000)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="49f168fd-8c06-45f5-bfff-ad3b19d1d455" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49f168fd-8c06-45f5-bfff-ad3b19d1d455")) {                    Plotly.newPlot(                        "49f168fd-8c06-45f5-bfff-ad3b19d1d455",                        [{"coloraxis":"coloraxis","name":"0","x":["Density","ArmedForcesSize","CallingCode","Co2-Emissions","Population","MinimumWage","LandArea","MaternalMortalityRatio","LifeExpectancy","UnemploymentRate","Urban_population","Longitude","AgriculturalLand","BirthRate","ForestedArea","CPI","CPIChange","FertilityRate","GrossPrimaryEducationEnrollment","Latitude","GrossTertiaryEducationEnrollment","GDP","GasolinePrice","PopulationLaborForceParticipation","TaxRevenue","TotalTaxRate","InfantMortality","OutOfPocketHealthExpenditure","PhysiciansPerThousand","GDP_per_Capita"],"y":["Density","ArmedForcesSize","CallingCode","Co2-Emissions","Population","MinimumWage","LandArea","MaternalMortalityRatio","LifeExpectancy","UnemploymentRate","Urban_population","Longitude","AgriculturalLand","BirthRate","ForestedArea","CPI","CPIChange","FertilityRate","GrossPrimaryEducationEnrollment","Latitude","GrossTertiaryEducationEnrollment","GDP","GasolinePrice","PopulationLaborForceParticipation","TaxRevenue","TotalTaxRate","InfantMortality","OutOfPocketHealthExpenditure","PhysiciansPerThousand","GDP_per_Capita"],"z":[[1.0,0.10259522351829034,0.05532426915365458,0.025075776873631744,0.13269494913904278,0.14621304177902117,-0.15265228333032843,-0.08557214860721404,0.20521947630963353,-0.17362354449928044,0.0795278977661623,0.0996263049378005,0.08787035597064892,-0.2085062502452674,-0.20002881976021702,-0.07339930082207972,-0.08946170262111722,-0.22060453398668103,0.03378906163527732,0.094256910500763,-0.004061054895898666,0.03472857549089276,0.2180035093449357,-0.10070927488026339,0.11386211616345339,-0.08454047250680716,-0.11235202715062907,0.1728934329340923,0.008008388224611467,0.17311397854038443],[0.10259522351829034,1.0,-0.2311613623992732,0.7697859356306376,0.9236162902967848,-0.06901396824047028,0.5678385693947455,-0.08793020364069369,0.06651156075189561,-0.04579459228807984,0.8876055100878337,0.2679305619709869,0.046203237288271054,-0.15372533663845256,-0.019689412775002448,0.038999977543141114,0.0825026947051614,-0.1580798316809678,0.03430421561143551,0.10666403486771074,0.08206174928336779,0.6772108711298933,-0.12847181610528327,-0.10453730533780924,-0.1894223088596976,0.17992829661652743,-0.044846701555757755,0.1621904786264172,-0.03171248255530891,-0.041765767888816224],[0.05532426915365458,-0.2311613623992732,1.0,-0.1472484378089106,-0.17526092051838424,-0.15634324821925716,-0.23553401704344956,-0.13793225827101255,-0.00879780245285733,0.021156751927342645,-0.19419794388500966,0.09453344307747369,-0.049731440897098106,0.06152751907636177,-0.19893448326698326,-0.051166454783852455,-0.041518450770683925,0.011352298609766135,-0.05677668791423731,0.09313195693028571,-0.14551057375203252,-0.17413941556127158,-0.15589752819485903,-0.03744043207818658,0.0013482452266505463,-0.3260022073958667,-0.06274629714333592,0.08504443212872702,0.04501320143028897,-0.11727557590971924],[0.025075776873631744,0.7697859356306376,-0.1472484378089106,1.0,0.8349120335619062,0.0008140094681686396,0.5362739962097326,-0.09985974446651365,0.10536850343217964,-0.0642934885915705,0.9385210376784366,0.18315626943992902,0.06150315743337953,-0.15603649157558,-0.027991502891837567,-0.014926412257132515,0.005035116930685576,-0.14006184801579646,-0.013092792238053489,0.11684379094801216,0.10771177928753922,0.9689629805183207,-0.04636383714711418,0.016034214045424093,-0.13726891837197847,0.1459614375140657,-0.11458892148545456,-0.007313566622081846,0.0358146080614 ...

# %% [markdown]
# <font size="+3" color="#000000"><b>3 <span style='color:#4285f4; font-weight:bold'>|</span> Exploratory Analysis </b></font><br><a id="1"></a>

# %%
fig = px.scatter(df, x="PhysiciansPerThousand", y="BirthRate", hover_data=df[['Country']])
fig.update_layout(
    title='Scatterplot of Birth Rate & Physicians per Thousand'
)
fig.update_traces(selector=dict(type='scatter'),
                  marker=dict(color='#ea4335'))

trendline = px.scatter(df, x="PhysiciansPerThousand", y="BirthRate",
                       trendline="ols", trendline_options=dict(log_x=True))
trendline.data[1]['line']['color'] = '#5591f5'
fig.add_trace(trendline.data[1])
fig.update_layout(
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)

fig.update_xaxes(title_text="Physicians per thousand")
fig.update_yaxes(title_text="Birth Rate")

fig.show()
# Out:
# <div>                            <div id="5df45cff-1379-4001-9215-1f29d7b46e65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5df45cff-1379-4001-9215-1f29d7b46e65")) {                    Plotly.newPlot(                        "5df45cff-1379-4001-9215-1f29d7b46e65",                        [{"customdata":[["Afghanistan"],["Albania"],["Algeria"],["Angola"],["Argentina"],["Armenia"],["Azerbaijan"],["Bangladesh"],["Barbados"],["Belgium"],["Belize"],["Benin"],["Botswana"],["Brazil"],["Bulgaria"],["Burkina Faso"],["Ivory Coast"],["Cape Verde"],["Cameroon"],["Canada"],["Chile"],["China"],["Colombia"],["Costa Rica"],["Croatia"],["Czech Republic"],["Democratic Republic of the Congo"],["Dominican Republic"],["Estonia"],["Fiji"],["France"],["Gabon"],["The Gambia"],["Georgia"],["Germany"],["Ghana"],["Greece"],["Guatemala"],["Honduras"],["Hungary"],["India"],["Indonesia"],["Iran"],["Iraq"],["Israel"],["Jamaica"],["Jordan"],["Kazakhstan"],["Kenya"],["Kuwait"],["Kyrgyzstan"],["Laos"],["Latvia"],["Lebanon"],["Lithuania"],["Luxembourg"],["Madagascar"],["Malawi"],["Malaysia"],["Mali"],["Malta"],["Mauritius"],["Moldova"],["Mongolia"],["Morocco"],["Mozambique"],["Myanmar"],["Nepal"],["New Zealand"],["Nicaragua"],["Niger"],["Nigeria"],["Oman"],["Pakistan"],["Papua New Guinea"],["Paraguay"],["Peru"],["Philippines"],["Poland"],["Portugal"],["Romania"],["Russia"],["Saudi Arabia"],["Senegal"],["Serbia"],["Sierra Leone"],["Slovakia"],["Slovenia"],["South Korea"],["Spain"],["Sri Lanka"],["Sudan"],["Syria"],["Tajikistan"],["Tanzania"],["Thailand"],["East Timor"],["Togo"],["Trinidad and Tobago"],["Tunisia"],["Turkey"],["Uganda"],["Ukraine"],["United Kingdom"],["Uruguay"],["Vietnam"],["Zambia"]],"hovertemplate":"PhysiciansPerThousand=%{x}\u003cbr\u003eBirthRate=%{y}\u003cbr\u003eCountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#ea4335","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.28,1.2,1.72,0.21,3.96,4.4,3.45,0.58,2.48,3.07,1.12,0.08,0.37,2.15,4.03,0.08,0.23,0.77,0.09,2.61,2.59,1.98,2.18,2.89,3.0,4.12,0.07,1.56,4.48,0.84,3.27,0.68,0.1,7.12,4.25,0.14,5.48,0.35,0.31,3.41,0.86,0.43,1.58,0.71,4.62,1.31,2.32,3.25,0.16,2.58,1.88,0.37,3.19,2.1,6.35,3.01,0.18,0.04,1.51,0.13,2.86,2.53,3.21,2.86,0.73,0.08,0.68,0.75,3.59,0.98,0.04,0.38,2.0,0.98,0.07,1.35,1.27,0.6,2.38,5.12,2.98,4.01,2.61,0.07,3.11,0.03,3.42,3.09,2.36,3.87,1.0,0.26,1.22,1.7,0.01,0.81,0.72,0.08,4.17,1.3,1.85,0.17,2.99,2.81,5.05,0.82,1.19],"xaxis":"x","y":[32.49,11.78,24.28,40.73,17.02,13.99,14.0,18.18,10.65,10.3,20.79,36.22,24.82,13.92,8.9,37.93,35.74,19.49,35.39,10.1,12.43,10.9,14.88,13.97,9.0,10.7,41.18,19.51,10.9,21.28,11.3,31.61,38.54,13.47,9.5,29.41,8.1,24.56,21.6,9.6,17.86,18.07,18.78,29.08,20.8,16.1,21.98,21.77,28.75,13.94,27.1,23.55,10.0,17.55,10.0,10.3,32.66,34.12,16.75,41.54,9.2,10.2,10.1,24.13,18.94,37.52,17.55,19.89,11.98,20.64,46.08,37.91,19.19,28.25,27.07,20.57,17.95,20.55,10.2,8.5,9.6,11.5,17.8,34.52,9.2,33.41,10.6,9.4,6.4,7.9,15.83,32.18,23.69,30.76,36.7,10.34,29.42,33.11,12.94,17.56,16.03,38.14,8.7,11.0,13.86,16.75,36.19],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eBirthRate = -13.7318 * log10(PhysiciansPerThousand) + 20.3439\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.716194\u003cbr\u003e\u003cbr\u003ePhysiciansPerThousand=%{x}\u003cbr\u003eBirthRate=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#5591f5"},"marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[0.01,0.03,0.04,0.04,0.07,0.07,0.07,0.08,0.08,0.08,0.08,0.09,0.1,0.13,0.14,0.16,0.17,0.18,0.21,0.23,0.26,0.28,0 ...
#
# var gd = document.getElementById('5df45cff-1379-4001-9215-1f29d7b46e65');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# **Birth Rate:**  Birth rate is an estimate of the number of individuals born per year per 1000 in the population.
# **Physicians Per Thousand:** A physician is a general term for a doctor who has earned a medical degree. This variable represents the number of physicians per thousand in the population of a country.
#
# From this graph, we can see that there is a negative relationship between these two variables, and the correlation is strong, with $R^2=0.716194$.
#
# But why?
# Shouldn't there be a positive relationship? If the number of physicians per thousand decreases, then the birth rate should also decrease. However, this isn't the case here.

# %%
fig = make_subplots(rows=1, cols=2)

scatter1 = px.scatter(df, x="PhysiciansPerThousand", y="InfantMortality",
                      trendline="ols", trendline_options=dict(log_x=True), hover_data=df[['Country']])
fig.add_trace(go.Scatter(scatter1.data[0], marker_color='#ea4335'), row=1, col=1)
fig.add_trace(go.Scatter(scatter1.data[1], line=dict(color='#5591f5')), row=1, col=1)

fig.update_xaxes(title_text="Physicians per thousand", row=1, col=1)
fig.update_yaxes(title_text="Infant Mortality", row=1, col=1)

scatter2 = px.scatter(df, x="PhysiciansPerThousand", y="MaternalMortalityRatio",
                      trendline="ols", trendline_options=dict(log_x=True), hover_data=df[['Country']])
fig.add_trace(go.Scatter(scatter2.data[0], marker_color='#34a853'), row=1, col=2)
fig.add_trace(go.Scatter(scatter2.data[1], line=dict(color='#5591f5')), row=1, col=2)

fig.update_xaxes(title_text="Physicians per thousand", row=1, col=2)
fig.update_yaxes(title_text="Maternal Mortality Ratio", row=1, col=2)

fig.update_layout(
    showlegend=False,
    template='plotly_white',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)

fig.show()
# Out:
# <div>                            <div id="bada532a-5db7-479d-9f26-a9d2b2788ef5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bada532a-5db7-479d-9f26-a9d2b2788ef5")) {                    Plotly.newPlot(                        "bada532a-5db7-479d-9f26-a9d2b2788ef5",                        [{"customdata":[["Afghanistan"],["Albania"],["Algeria"],["Angola"],["Argentina"],["Armenia"],["Azerbaijan"],["Bangladesh"],["Barbados"],["Belgium"],["Belize"],["Benin"],["Botswana"],["Brazil"],["Bulgaria"],["Burkina Faso"],["Ivory Coast"],["Cape Verde"],["Cameroon"],["Canada"],["Chile"],["China"],["Colombia"],["Costa Rica"],["Croatia"],["Czech Republic"],["Democratic Republic of the Congo"],["Dominican Republic"],["Estonia"],["Fiji"],["France"],["Gabon"],["The Gambia"],["Georgia"],["Germany"],["Ghana"],["Greece"],["Guatemala"],["Honduras"],["Hungary"],["India"],["Indonesia"],["Iran"],["Iraq"],["Israel"],["Jamaica"],["Jordan"],["Kazakhstan"],["Kenya"],["Kuwait"],["Kyrgyzstan"],["Laos"],["Latvia"],["Lebanon"],["Lithuania"],["Luxembourg"],["Madagascar"],["Malawi"],["Malaysia"],["Mali"],["Malta"],["Mauritius"],["Moldova"],["Mongolia"],["Morocco"],["Mozambique"],["Myanmar"],["Nepal"],["New Zealand"],["Nicaragua"],["Niger"],["Nigeria"],["Oman"],["Pakistan"],["Papua New Guinea"],["Paraguay"],["Peru"],["Philippines"],["Poland"],["Portugal"],["Romania"],["Russia"],["Saudi Arabia"],["Senegal"],["Serbia"],["Sierra Leone"],["Slovakia"],["Slovenia"],["South Korea"],["Spain"],["Sri Lanka"],["Sudan"],["Syria"],["Tajikistan"],["Tanzania"],["Thailand"],["East Timor"],["Togo"],["Trinidad and Tobago"],["Tunisia"],["Turkey"],["Uganda"],["Ukraine"],["United Kingdom"],["Uruguay"],["Vietnam"],["Zambia"]],"hovertemplate":"PhysiciansPerThousand=%{x}\u003cbr\u003eInfantMortality=%{y}\u003cbr\u003eCountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#ea4335","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.28,1.2,1.72,0.21,3.96,4.4,3.45,0.58,2.48,3.07,1.12,0.08,0.37,2.15,4.03,0.08,0.23,0.77,0.09,2.61,2.59,1.98,2.18,2.89,3.0,4.12,0.07,1.56,4.48,0.84,3.27,0.68,0.1,7.12,4.25,0.14,5.48,0.35,0.31,3.41,0.86,0.43,1.58,0.71,4.62,1.31,2.32,3.25,0.16,2.58,1.88,0.37,3.19,2.1,6.35,3.01,0.18,0.04,1.51,0.13,2.86,2.53,3.21,2.86,0.73,0.08,0.68,0.75,3.59,0.98,0.04,0.38,2.0,0.98,0.07,1.35,1.27,0.6,2.38,5.12,2.98,4.01,2.61,0.07,3.11,0.03,3.42,3.09,2.36,3.87,1.0,0.26,1.22,1.7,0.01,0.81,0.72,0.08,4.17,1.3,1.85,0.17,2.99,2.81,5.05,0.82,1.19],"xaxis":"x","y":[47.9,7.8,20.1,51.6,8.8,11.0,19.2,25.1,11.3,2.9,11.2,60.5,30.0,12.8,5.9,49.0,59.4,16.7,50.6,4.3,6.2,7.4,12.2,7.6,4.0,2.7,68.2,24.1,2.1,21.6,3.4,32.7,39.0,8.7,3.1,34.9,3.6,22.1,15.1,3.6,29.9,21.1,12.4,22.5,3.0,12.4,13.9,8.8,30.6,6.7,16.9,37.6,3.3,6.4,3.3,1.9,38.2,35.3,6.7,62.0,6.1,13.6,13.6,14.0,19.2,54.0,36.8,26.7,4.7,15.7,48.0,75.7,9.8,57.2,38.0,17.2,11.1,22.5,3.8,3.1,6.1,6.1,6.0,31.8,4.8,78.5,4.6,1.7,2.7,2.5,6.4,42.1,14.0,30.4,37.6,7.8,39.3,47.4,16.4,14.6,9.1,33.8,7.5,3.6,6.4,16.5,40.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eInfantMortality = -24.5092 * log10(PhysiciansPerThousand) + 20.6058\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.677729\u003cbr\u003e\u003cbr\u003ePhysiciansPerThousand=%{x}\u003cbr\u003eInfantMortality=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#5591f5"},"marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[0.01,0.03,0.04,0.04,0.07,0.07,0.07,0.08,0.08,0.08,0.08,0.09,0.1,0.13,0.14,0.16,0.17,0.18,0.21,0.23,0.26,0.28,0.31,0.35,0.37,0.37,0.38,0.43,0.58,0.6,0.68,0.68,0.71,0.72,0.73,0.75,0.77,0.81,0.82,0 ...

# %% [markdown]
# **Infant Mortality:** The infant mortality rate is the number of infant deaths for every 1000 live births.
# **Maternal Mortality Ratio:** The maternal mortality ratio is defined as the number of maternal deaths during a given time period per 100,000 live births during the same time period.
#
# This one makes sense. The infant mortality rate and the maternal mortality ratio increases exponentially as the number of physician per thousand decreases.
# The correlation is strong, $R^2 = 0.677729$
# This graph indicates that physicians are important for child births. Without them, the number of infant deaths and maternal deaths increases.
# Then why do countries with a low number of physicians (compared to their population) has a higher birth rate?
# Let's explore and find out!

# %%
fig = make_subplots(rows=1, cols=2)

scatter1 = px.scatter(df, x="PhysiciansPerThousand", y="GDP_per_Capita",
                      trendline="ols", trendline_options=dict(log_x=False), hover_data=df[['Country']])
fig.add_trace(go.Scatter(scatter1.data[0], marker_color='#5591f5'), row=1, col=1)
fig.add_trace(go.Scatter(scatter1.data[1], line=dict(color='#ea4335')), row=1, col=1)

fig.update_xaxes(title_text="Physicians per thousand", row=1, col=1)
fig.update_yaxes(title_text="GDP per Capita", row=1, col=1)

scatter2 = px.scatter(df, x="BirthRate", y="GDP_per_Capita",
                      trendline="ols", trendline_options=dict(log_x=True), hover_data=df[['Country']])
fig.add_trace(go.Scatter(scatter2.data[0], marker_color='#34a853'), row=1, col=2)
fig.add_trace(go.Scatter(scatter2.data[1], line=dict(color='#ea4335')), row=1, col=2)

fig.update_xaxes(title_text="Birth Rate", row=1, col=2)
fig.update_yaxes(title_text="GDP per Capita", row=1, col=2)

fig.update_layout(
    showlegend=False,
    template='plotly_white',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)

fig.show()
# Out:
# <div>                            <div id="75146a81-f0a0-4488-9781-ba1c291c967b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75146a81-f0a0-4488-9781-ba1c291c967b")) {                    Plotly.newPlot(                        "75146a81-f0a0-4488-9781-ba1c291c967b",                        [{"customdata":[["Afghanistan"],["Albania"],["Algeria"],["Angola"],["Argentina"],["Armenia"],["Azerbaijan"],["Bangladesh"],["Barbados"],["Belgium"],["Belize"],["Benin"],["Botswana"],["Brazil"],["Bulgaria"],["Burkina Faso"],["Ivory Coast"],["Cape Verde"],["Cameroon"],["Canada"],["Chile"],["China"],["Colombia"],["Costa Rica"],["Croatia"],["Czech Republic"],["Democratic Republic of the Congo"],["Dominican Republic"],["Estonia"],["Fiji"],["France"],["Gabon"],["The Gambia"],["Georgia"],["Germany"],["Ghana"],["Greece"],["Guatemala"],["Honduras"],["Hungary"],["India"],["Indonesia"],["Iran"],["Iraq"],["Israel"],["Jamaica"],["Jordan"],["Kazakhstan"],["Kenya"],["Kuwait"],["Kyrgyzstan"],["Laos"],["Latvia"],["Lebanon"],["Lithuania"],["Luxembourg"],["Madagascar"],["Malawi"],["Malaysia"],["Mali"],["Malta"],["Mauritius"],["Moldova"],["Mongolia"],["Morocco"],["Mozambique"],["Myanmar"],["Nepal"],["New Zealand"],["Nicaragua"],["Niger"],["Nigeria"],["Oman"],["Pakistan"],["Papua New Guinea"],["Paraguay"],["Peru"],["Philippines"],["Poland"],["Portugal"],["Romania"],["Russia"],["Saudi Arabia"],["Senegal"],["Serbia"],["Sierra Leone"],["Slovakia"],["Slovenia"],["South Korea"],["Spain"],["Sri Lanka"],["Sudan"],["Syria"],["Tajikistan"],["Tanzania"],["Thailand"],["East Timor"],["Togo"],["Trinidad and Tobago"],["Tunisia"],["Turkey"],["Uganda"],["Ukraine"],["United Kingdom"],["Uruguay"],["Vietnam"],["Zambia"]],"hovertemplate":"PhysiciansPerThousand=%{x}\u003cbr\u003eGDP_per_Capita=%{y}\u003cbr\u003eCountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#5591f5","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.28,1.2,1.72,0.21,3.96,4.4,3.45,0.58,2.48,3.07,1.12,0.08,0.37,2.15,4.03,0.08,0.23,0.77,0.09,2.61,2.59,1.98,2.18,2.89,3.0,4.12,0.07,1.56,4.48,0.84,3.27,0.68,0.1,7.12,4.25,0.14,5.48,0.35,0.31,3.41,0.86,0.43,1.58,0.71,4.62,1.31,2.32,3.25,0.16,2.58,1.88,0.37,3.19,2.1,6.35,3.01,0.18,0.04,1.51,0.13,2.86,2.53,3.21,2.86,0.73,0.08,0.68,0.75,3.59,0.98,0.04,0.38,2.0,0.98,0.07,1.35,1.27,0.6,2.38,5.12,2.98,4.01,2.61,0.07,3.11,0.03,3.42,3.09,2.36,3.87,1.0,0.26,1.22,1.7,0.01,0.81,0.72,0.08,4.17,1.3,1.85,0.17,2.99,2.81,5.05,0.82,1.19],"xaxis":"x","y":[502.11548691997746,5352.857411084262,3948.3432789227913,2973.591159799147,10006.148973606541,4622.733493343377,3911.5789801341234,1808.4378618138294,18148.24492640014,46116.699233676605,4815.163710795101,1219.4326718639563,7817.1830832174355,8655.264804221777,12328.404026456756,774.8396902513206,2286.16277684902,4097.872209632196,1497.90917558793,46940.59584210967,14896.453866597354,14244.677920749224,6432.387583390623,12238.374964463035,14853.239837492318,23101.777704996453,545.2162123102618,8282.11622189043,23566.890205462583,6220.046420428944,40493.9285720389,7667.366861228061,751.2946885172164,4769.18654320981,46258.8782897109,2175.3153946557563,19582.53601086268,4619.987097105244,2574.912190670397,16475.741838979917,1910.8358277376421,4142.022784788127,5371.177207873912,5955.109010370268,43641.39773585323,5582.263777613991,4330.329345949303,9731.14520687936,1816.5469164371505,32031.980102603156,1309.3929916833156,2534.8982772051713,17836.364886560932,7784.316856904599,19455.45412660343,110172.37314087298,522.219809244635,411.5523404231106,11239.78150436468,890.7372854890706,29416.230606402427,11203.540584699034,4498.520850289186,4295.235024728952,3216.5667385160236,491.80472307942995,1407.8131434078966,1071.0 ...

# %% [markdown]
# Now it's making some sense. In poor countries,
# - The number of physician per thousand is low.
# - The birth rate is high.
# - The infant mortality rate and maternal mortality ratio is high.
#
# In poor countries, birth rates are high because children are needed to work and bring in an income for the family. Children are required to look after elderly parents because of a lack of pensions.
# This is why, in poor countries, even though the number of physicians are low, the birth rate is high, leading to a high infant mortality rate and a high maternal mortality ratio.

# %%
df['Log_GDP_per_Capita'] = df['GDP_per_Capita'].apply(lambda x: math.log(x))

fig = px.scatter(df, x="BirthRate", y="LifeExpectancy", color="Log_GDP_per_Capita",
                 trendline="ols", color_continuous_scale="sunset", hover_data=df[['Country']])

color_scale_label = "GDP per Capita<br>(log scale)<br> ."
fig.update_coloraxes(colorbar_title=color_scale_label)

color_scale_ticks = [math.log(val) for val in [100, 1000, 10000, 100000]]
color_scale_ticklabels = ["100", "1,000", "10,000", "100,000"]
fig.update_coloraxes(colorbar_ticks="outside", colorbar_tickvals=color_scale_ticks, colorbar_ticktext=color_scale_ticklabels)

fig.update_xaxes(title_text="Birth Rate")
fig.update_yaxes(title_text="Life Expectancy")

fig.update_layout(
    title='Scatterplot of BirthRate & LifeExpectancy',
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)

fig.show()
# Out:
# <div>                            <div id="6dc9642f-9d53-452b-9aa4-eade1b726147" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dc9642f-9d53-452b-9aa4-eade1b726147")) {                    Plotly.newPlot(                        "6dc9642f-9d53-452b-9aa4-eade1b726147",                        [{"customdata":[["Afghanistan"],["Albania"],["Algeria"],["Angola"],["Argentina"],["Armenia"],["Azerbaijan"],["Bangladesh"],["Barbados"],["Belgium"],["Belize"],["Benin"],["Botswana"],["Brazil"],["Bulgaria"],["Burkina Faso"],["Ivory Coast"],["Cape Verde"],["Cameroon"],["Canada"],["Chile"],["China"],["Colombia"],["Costa Rica"],["Croatia"],["Czech Republic"],["Democratic Republic of the Congo"],["Dominican Republic"],["Estonia"],["Fiji"],["France"],["Gabon"],["The Gambia"],["Georgia"],["Germany"],["Ghana"],["Greece"],["Guatemala"],["Honduras"],["Hungary"],["India"],["Indonesia"],["Iran"],["Iraq"],["Israel"],["Jamaica"],["Jordan"],["Kazakhstan"],["Kenya"],["Kuwait"],["Kyrgyzstan"],["Laos"],["Latvia"],["Lebanon"],["Lithuania"],["Luxembourg"],["Madagascar"],["Malawi"],["Malaysia"],["Mali"],["Malta"],["Mauritius"],["Moldova"],["Mongolia"],["Morocco"],["Mozambique"],["Myanmar"],["Nepal"],["New Zealand"],["Nicaragua"],["Niger"],["Nigeria"],["Oman"],["Pakistan"],["Papua New Guinea"],["Paraguay"],["Peru"],["Philippines"],["Poland"],["Portugal"],["Romania"],["Russia"],["Saudi Arabia"],["Senegal"],["Serbia"],["Sierra Leone"],["Slovakia"],["Slovenia"],["South Korea"],["Spain"],["Sri Lanka"],["Sudan"],["Syria"],["Tajikistan"],["Tanzania"],["Thailand"],["East Timor"],["Togo"],["Trinidad and Tobago"],["Tunisia"],["Turkey"],["Uganda"],["Ukraine"],["United Kingdom"],["Uruguay"],["Vietnam"],["Zambia"]],"hovertemplate":"BirthRate=%{x}\u003cbr\u003eLifeExpectancy=%{y}\u003cbr\u003eCountry=%{customdata[0]}\u003cbr\u003eLog_GDP_per_Capita=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[6.218830146858905,8.585385792841569,8.281051346855193,7.9975256460835284,9.210955080364917,8.438741474336764,8.271696402697872,7.500218691837993,9.806329136747452,10.738930402734134,8.479525323819363,7.106141006508215,8.964079549107302,9.065923062661835,9.419661149536966,6.6526561566680495,7.734630047790431,8.318223144718726,7.3118255317904195,10.756638163020865,9.60887846807774,9.564138636690384,8.76910106765505,9.412331782911096,9.605973291309946,10.047664850475106,6.301182435826079,9.021853797077616,10.067598048551876,8.735532648796847,10.608907330055224,8.94472853179827,6.6217979696272655,8.469931033324752,10.742008687538805,7.68492894204712,9.882393428170518,8.438147191237523,7.853570711805869,9.709644386519637,7.555296031464393,8.328939542854965,8.588802382821234,8.692004787309555,10.683761468211669,8.627349668016327,8.373398879524174,9.183086866802872,7.504692679258991,10.374490060942275,7.177318943681162,7.837908787884922,9.788994623407637,8.9598663292173,9.87588272755709,11.60980144681985,6.258088589755876,6.019936206252466,9.327214684145277,6.792049530445335,10.289301862439176,9.32398513096048,8.41150392178901,8.365261553463489,8.076069839436057,6.198081733394843,7.24979281726335,6.976395464800893,10.663008574257624,7.556377652100454,6.3182488798374825,7.709693497534317,9.589968479290068,7.248205703260294,7.953381678746404,8.596891065109808,8.850474024288545,8.156247488862233,9.654720187027388,10.049535817011547,9.466495371425182,9.373662271688344,10.049309299591894,7.277130902249504,8.909553412184717,6.22349359203445,9.869366845858153,10.155772258281766,10.577419875986498,10.295991396456179,8.256629065876442,6.090190711659288,7.76937852195058,6.769398077186603,6.99315947319235,8.962928835306249,6.16993363313287,6.515515647500374,9.757100475544565,8.106979128906785,9.109690187811953,6.65514246285 ...

# %% [markdown]
# There is a negative linear relationship between life expectancy and birth rate. This is because countries with higher birth rates have a lower GDP per Capita, so the people in these countries cannot afford the essential things needed to maintain a good lifestyle, such as healthcare, clean environment etc. Therefore, the life expectancy is low.
# Sierra Leone and Nigeria are the 2 countries with the lowest life expectancies, just 54.3 years!

# %%
fig = px.scatter(df, x="GDP_per_Capita", y="LifeExpectancy",
                 trendline="ols", trendline_options=dict(log_x=True), hover_data=df[['Country']])
fig.update_layout(
    title='Scatterplot of GDP per Capita & Life Expectancy'
)

trendline = px.scatter(df, x="GDP_per_Capita", y="LifeExpectancy",
                       trendline="ols", trendline_options=dict(log_x=True))
trendline.data[1]['line']['color'] = '#ea4335'
fig.add_trace(trendline.data[1])

fig.update_xaxes(title_text="GDP per Capita")
fig.update_yaxes(title_text="Life Expectancy")

fig.update_layout(
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)

fig.show()
# Out:
# <div>                            <div id="445b5e73-ae59-47e0-bccb-1f488ee7da96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("445b5e73-ae59-47e0-bccb-1f488ee7da96")) {                    Plotly.newPlot(                        "445b5e73-ae59-47e0-bccb-1f488ee7da96",                        [{"customdata":[["Afghanistan"],["Albania"],["Algeria"],["Angola"],["Argentina"],["Armenia"],["Azerbaijan"],["Bangladesh"],["Barbados"],["Belgium"],["Belize"],["Benin"],["Botswana"],["Brazil"],["Bulgaria"],["Burkina Faso"],["Ivory Coast"],["Cape Verde"],["Cameroon"],["Canada"],["Chile"],["China"],["Colombia"],["Costa Rica"],["Croatia"],["Czech Republic"],["Democratic Republic of the Congo"],["Dominican Republic"],["Estonia"],["Fiji"],["France"],["Gabon"],["The Gambia"],["Georgia"],["Germany"],["Ghana"],["Greece"],["Guatemala"],["Honduras"],["Hungary"],["India"],["Indonesia"],["Iran"],["Iraq"],["Israel"],["Jamaica"],["Jordan"],["Kazakhstan"],["Kenya"],["Kuwait"],["Kyrgyzstan"],["Laos"],["Latvia"],["Lebanon"],["Lithuania"],["Luxembourg"],["Madagascar"],["Malawi"],["Malaysia"],["Mali"],["Malta"],["Mauritius"],["Moldova"],["Mongolia"],["Morocco"],["Mozambique"],["Myanmar"],["Nepal"],["New Zealand"],["Nicaragua"],["Niger"],["Nigeria"],["Oman"],["Pakistan"],["Papua New Guinea"],["Paraguay"],["Peru"],["Philippines"],["Poland"],["Portugal"],["Romania"],["Russia"],["Saudi Arabia"],["Senegal"],["Serbia"],["Sierra Leone"],["Slovakia"],["Slovenia"],["South Korea"],["Spain"],["Sri Lanka"],["Sudan"],["Syria"],["Tajikistan"],["Tanzania"],["Thailand"],["East Timor"],["Togo"],["Trinidad and Tobago"],["Tunisia"],["Turkey"],["Uganda"],["Ukraine"],["United Kingdom"],["Uruguay"],["Vietnam"],["Zambia"]],"hovertemplate":"GDP_per_Capita=%{x}\u003cbr\u003eLifeExpectancy=%{y}\u003cbr\u003eCountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[502.11548691997746,5352.857411084262,3948.3432789227913,2973.591159799147,10006.148973606541,4622.733493343377,3911.5789801341234,1808.4378618138294,18148.24492640014,46116.699233676605,4815.163710795101,1219.4326718639563,7817.1830832174355,8655.264804221777,12328.404026456756,774.8396902513206,2286.16277684902,4097.872209632196,1497.90917558793,46940.59584210967,14896.453866597354,14244.677920749224,6432.387583390623,12238.374964463035,14853.239837492318,23101.777704996453,545.2162123102618,8282.11622189043,23566.890205462583,6220.046420428944,40493.9285720389,7667.366861228061,751.2946885172164,4769.18654320981,46258.8782897109,2175.3153946557563,19582.53601086268,4619.987097105244,2574.912190670397,16475.741838979917,1910.8358277376421,4142.022784788127,5371.177207873912,5955.109010370268,43641.39773585323,5582.263777613991,4330.329345949303,9731.14520687936,1816.5469164371505,32031.980102603156,1309.3929916833156,2534.8982772051713,17836.364886560932,7784.316856904599,19455.45412660343,110172.37314087298,522.219809244635,411.5523404231106,11239.78150436468,890.7372854890706,29416.230606402427,11203.540584699034,4498.520850289186,4295.235024728952,3216.5667385160236,491.80472307942995,1407.8131434078966,1071.0507605550897,42745.04555752943,1912.903745350624,554.6009686961554,2229.858696245781,14617.408775978893,1405.5805556086316,2845.180185774812,5414.799137954041,6977.695783568442,3485.0842183692116,15595.227033436207,23145.04081731222,12919.529644186483,11774.156384485565,23139.798656131363,1446.8309649931728,7402.354558655718,504.4625433960284,19329.0968008679,25739.247814359183,39238.74286107253,29613.67113798626,3853.0836928863,441.5056033837011,2366.999792737433,870.787589295504,1089.1572087787663,7808.192916304814,478.15437142857144,675.5422 ...

# %% [markdown]
# Life expectancy and GDP per Capita have a strong correlation.
# Or in other words, poor countries have a lower life expectancy compared to rich countries.

# %%
data = df[['Country', 'GDP_per_Capita']].sort_values('GDP_per_Capita', ascending=False)[:10]
colors = ['#a1c2fa', '#f28e86', '#fde396', '#aedcba', '#a1c2fa', '#f28e86', '#fcd050', '#5db975', '#5591f5', '#ea4335']
fig = go.Figure(go.Bar(
    x=data['GDP_per_Capita'][::-1],
    y=data['Country'][::-1],
    marker=dict(color=colors),
    orientation='h',
    text=data['GDP_per_Capita'].apply(lambda x:"$"+str(round(x/1000))+'k')[::-1],
    textposition='outside',
))
fig.update_layout(
    title='Top 10 Richest Countries in the World (by GDP per Capita)',
    xaxis_title="GDP per Capita",
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)

fig.show()
# Out:
# <div>                            <div id="c1dc3c55-07ee-4424-8069-f3aeac469015" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1dc3c55-07ee-4424-8069-f3aeac469015")) {                    Plotly.newPlot(                        "c1dc3c55-07ee-4424-8069-f3aeac469015",                        [{"marker":{"color":["#a1c2fa","#f28e86","#fde396","#aedcba","#a1c2fa","#f28e86","#fcd050","#5db975","#5591f5","#ea4335"]},"orientation":"h","text":["$32k","$39k","$40k","$42k","$43k","$44k","$46k","$46k","$47k","$110k"],"textposition":"outside","x":[32031.980102603156,39238.74286107253,40493.9285720389,42300.26712583137,42745.04555752943,43641.39773585323,46116.699233676605,46258.8782897109,46940.59584210967,110172.37314087298],"y":["Kuwait","South Korea","France","United Kingdom","New Zealand","Israel","Belgium","Germany","Canada","Luxembourg"],"type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"title":{"text":"Top 10 Richest Countries in the World (by GDP per Capita)"},"xaxis":{"title":{"text":"GDP per Capita"}},"plot_bgcolor":"rgba(0, 0, 0, 0)","paper_bgcolor":"rgba(0, 0, 0, 0)"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('c1dc3c55-07ee-4424-8069-f3aeac469015');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# Why isn't USA present on this list? The author didn't include USA in this dataset, that's why (if you're the author, it would be great if you could add it to the dataset). Otherwise USA would be second on this list, with a GDP per Capita of 70,000 USD.

# %%
data = df[['Country', 'Population']].sort_values('Population', ascending=False)[:10]
colors = ['#a1c2fa', '#f28e86', '#fde396', '#aedcba', '#a1c2fa', '#f28e86', '#fcd050', '#5db975', '#5591f5', '#ea4335']
fig = go.Figure(go.Bar(
            x=data['Population'][::-1],
            y=data['Country'][::-1],
            marker=dict(color=colors),
            text=data['Population'].apply(lambda x:str(int(x/1000000))+"M")[::-1], 
            textposition='outside',
            orientation='h'))
fig.update_layout(
    title='Top 10 Most Populated Countries in the World',
    xaxis_title="Population Size",
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)

fig.show()

df_sorted = df.sort_values('Population', ascending=False)

top_n = 2
top_countries = df_sorted.head(top_n)

other_population = df_sorted.iloc[top_n:]['Population'].sum()

new_df = pd.concat([top_countries, pd.DataFrame({'Country': ['Others'], 'Population': [other_population]})])

colors = ['#4285f4', '#ea4335', '#34a853']
fig = go.Figure(data=[go.Pie(labels=new_df['Country'],
                             values=new_df['Population'],
                             textinfo="label+percent",
                             pull=[0, 0, 0],
                             showlegend=False,
                             marker_colors=colors,
                            )])


fig.update_traces(
    hole=0.6
)
fig.update_layout(
    title='Population distribution of Countries',
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
    annotations=[
        dict(
            text="Almost Half of the Earth's <br>Population lives in <br> India & China alone!!", 
            x=0.5, y=0.5, 
            font_size=13,
            showarrow=False
        )
    ]
)

fig.show()
# Out:
# <div>                            <div id="deb678d8-a35f-4729-b85f-02b0ab797083" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("deb678d8-a35f-4729-b85f-02b0ab797083")) {                    Plotly.newPlot(                        "deb678d8-a35f-4729-b85f-02b0ab797083",                        [{"marker":{"color":["#a1c2fa","#f28e86","#fde396","#aedcba","#a1c2fa","#f28e86","#fcd050","#5db975","#5591f5","#ea4335"]},"orientation":"h","text":["96M","108M","144M","167M","200M","212M","216M","270M","1366M","1397M"],"textposition":"outside","x":[96462106,108116615,144373535,167310838,200963599,212559417,216565318,270203917,1366417754,1397715000],"y":["Vietnam","Philippines","Russia","Bangladesh","Nigeria","Brazil","Pakistan","Indonesia","India","China"],"type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"title":{"text":"Top 10 Most Populated Countries in the World"},"xaxis":{"title":{"text":"Population Size"}},"plot_bgcolor":"rgba(0, 0, 0, 0)","paper_bgcolor":"rgba(0, 0, 0, 0)"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('deb678d8-a35f-4729-b85f-02b0ab797083');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
# <div>                            <div id="0ae8f1f6-d07a-43ad-9f0d-3c955955f8b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ae8f1f6-d07a-43ad-9f0d-3c955955f8b8")) {                    Plotly.newPlot(                        "0ae8f1f6-d07a-43ad-9f0d-3c955955f8b8",                        [{"labels":["China","India","Others"],"marker":{"colors":["#4285f4","#ea4335","#34a853"]},"pull":[0,0,0],"showlegend":false,"textinfo":"label+percent","values":[1397715000,1366417754,3489642965],"type":"pie","hole":0.6}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"title":{"text":"Population distribution of Countries"},"plot_bgcolor":"rgba(0, 0, 0, 0)","paper_bgcolor":"rgba(0, 0, 0, 0)","annotations":[{"showarrow":false,"text":"Almost Half of the Earth's \u003cbr\u003ePopulation lives in \u003cbr\u003e India & China alone!!","x":0.5,"y":0.5,"font":{"size":13}}]},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('0ae8f1f6-d07a-43ad-9f0d-3c955955f8b8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
fig = make_subplots(rows=1, cols=2)

scatter1 = px.scatter(df, x="Urban_population", y="Co2-Emissions",
                      trendline="ols", trendline_options=dict(log_x=False), hover_data=df[['Country']])
fig.add_trace(go.Scatter(scatter1.data[0], marker_color='#34a853'), row=1, col=1)
fig.add_trace(go.Scatter(scatter1.data[1], line=dict(color='#ea4335')), row=1, col=1)

fig.update_xaxes(title_text="Urban_population", row=1, col=1)
fig.update_yaxes(title_text="Co2-Emissions", row=1, col=1)

scatter2 = px.scatter(df, x="Population", y="Co2-Emissions",
                      trendline="ols", trendline_options=dict(log_x=False), hover_data=df[['Country']])
fig.add_trace(go.Scatter(scatter2.data[0], marker_color='#4285f4'), row=1, col=2)
fig.add_trace(go.Scatter(scatter2.data[1], line=dict(color='#ea4335')), row=1, col=2)

fig.update_xaxes(title_text="Population", row=1, col=2)
fig.update_yaxes(title_text="Co2-Emissions", row=1, col=2)

fig.update_layout(
    showlegend=False,
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)

fig.show()
# Out:
# <div>                            <div id="514da9d0-8c43-47ce-8dce-507e9f5f05f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("514da9d0-8c43-47ce-8dce-507e9f5f05f0")) {                    Plotly.newPlot(                        "514da9d0-8c43-47ce-8dce-507e9f5f05f0",                        [{"customdata":[["Afghanistan"],["Albania"],["Algeria"],["Angola"],["Argentina"],["Armenia"],["Azerbaijan"],["Bangladesh"],["Barbados"],["Belgium"],["Belize"],["Benin"],["Botswana"],["Brazil"],["Bulgaria"],["Burkina Faso"],["Ivory Coast"],["Cape Verde"],["Cameroon"],["Canada"],["Chile"],["China"],["Colombia"],["Costa Rica"],["Croatia"],["Czech Republic"],["Democratic Republic of the Congo"],["Dominican Republic"],["Estonia"],["Fiji"],["France"],["Gabon"],["The Gambia"],["Georgia"],["Germany"],["Ghana"],["Greece"],["Guatemala"],["Honduras"],["Hungary"],["India"],["Indonesia"],["Iran"],["Iraq"],["Israel"],["Jamaica"],["Jordan"],["Kazakhstan"],["Kenya"],["Kuwait"],["Kyrgyzstan"],["Laos"],["Latvia"],["Lebanon"],["Lithuania"],["Luxembourg"],["Madagascar"],["Malawi"],["Malaysia"],["Mali"],["Malta"],["Mauritius"],["Moldova"],["Mongolia"],["Morocco"],["Mozambique"],["Myanmar"],["Nepal"],["New Zealand"],["Nicaragua"],["Niger"],["Nigeria"],["Oman"],["Pakistan"],["Papua New Guinea"],["Paraguay"],["Peru"],["Philippines"],["Poland"],["Portugal"],["Romania"],["Russia"],["Saudi Arabia"],["Senegal"],["Serbia"],["Sierra Leone"],["Slovakia"],["Slovenia"],["South Korea"],["Spain"],["Sri Lanka"],["Sudan"],["Syria"],["Tajikistan"],["Tanzania"],["Thailand"],["East Timor"],["Togo"],["Trinidad and Tobago"],["Tunisia"],["Turkey"],["Uganda"],["Ukraine"],["United Kingdom"],["Uruguay"],["Vietnam"],["Zambia"]],"hovertemplate":"Urban_population=%{x}\u003cbr\u003eCo2-Emissions=%{y}\u003cbr\u003eCountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#34a853","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[9797273,1747593,31510100,21061025,41339571,1869848,5616165,60987417,89431,11259082,179039,5648149,1616550,183241641,5256027,6092349,13176900,364029,14741256,30628482,16610135,842933962,40827302,4041885,2328318,7887156,39095679,8787475,916024,505048,54123364,1949694,1453958,2196476,64324835,17249054,8507474,8540945,5626433,6999582,471031528,151509724,62509623,27783368,8374393,1650594,9213048,10652915,14461523,4207083,2362644,2555552,1304943,6084994,1891013,565488,10210849,3199301,24475766,8479688,475902,515980,1135502,2210626,22975026,11092106,16674093,5765513,4258860,3846137,3850231,102806948,4250777,79927762,1162834,4359150,25390339,50975903,22796574,6753579,10468793,107683889,28807838,7765706,3907243,3319366,2930419,1144654,42106719,37927409,4052088,14957233,9358019,2545477,20011885,35294600,400182,3414638,741944,8099061,63097818,10784516,30835699,55908316,3303394,35332140,7871713],"xaxis":"x","y":[8672,4536,150006,34693,201348,5156,37620,84246,1276,96889,568,6476,6340,462299,41708,3418,9674,543,8291,544894,85822,9893038,97814,8023,17488,102218,2021,25258,16590,2046,303276,5321,532,10128,727973,16670,62434,16777,9813,45537,2407672,563325,661710,190061,65166,8225,25108,247207,17910,98734,9787,17763,7004,24796,12963,8988,3905,1298,248289,3179,1342,4349,5115,25368,61276,7943,25280,9105,34382,5592,2017,120369,63457,201150,7536,7407,57414,122287,299037,48742,69259,1732027,563449,10902,45221,1093,32424,12633,620302,244002,23362,20000,28830,5310,11973,283763,495,3000,43868,29937,372725,5680,202250,379025,6766,192668,5141],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eCo2-Emissions = 0.00980952 * Urban_population + -82242.3\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.880822\u003cbr\u003e\ ...

# %% [markdown]
# Both of these two plots have a strong positive correlation.
# - $R^2$ for urban population = 0.880822
# - $R^2$ for population = 0.697078
#
# Nothing unusual here... the greater the size of a country's population, the greater the amount of carbon dioxide emmisions is.
# As the correlation is stronger for urban population, it is a better indicator for the carbon dioxide emmisions of a country.
# If you hover over the regression line on the graphs, you can see the equation of the lines.
# - Gradient of regression line for `Urban_population` = 0.00980952
# - Gradient of regression line for `Population` = 0.004327502
#
# This means that the carbon dioxide emmisions for a country increases with a higher factor (about 2.3x) for their increase in urban population size compared to their general population size.
# Therefore, as expected, urbanization is more responsible for carbon dioxide emmisions of a country.

# %%
data = df[['Country', 'LandArea']].sort_values('LandArea', ascending=False)[:10]
colors = ['#a1c2fa', '#f28e86', '#fde396', '#aedcba', '#a1c2fa', '#f28e86', '#fcd050', '#5db975', '#5591f5', '#ea4335']
fig = go.Figure(go.Bar(
            x=data['LandArea'][::-1],
            y=data['Country'][::-1],
            marker=dict(color=colors),
            orientation='h'))
fig.update_layout(
    title='Top 10 Biggest Countries in the World by Land Area',
    xaxis_title="Land Area in square kilometers",
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
    margin=dict(l=220)  # Adjust the left margin to make room for long labels
)
fig.show()
# Out:
# <div>                            <div id="217a0394-31c4-4140-92ce-ae7e76a1e83b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("217a0394-31c4-4140-92ce-ae7e76a1e83b")) {                    Plotly.newPlot(                        "217a0394-31c4-4140-92ce-ae7e76a1e83b",                        [{"marker":{"color":["#a1c2fa","#f28e86","#fde396","#aedcba","#a1c2fa","#f28e86","#fcd050","#5db975","#5591f5","#ea4335"]},"orientation":"h","x":[2149690,2344858,2381741,2724900,2780400,3287263,8515770,9596960,9984670,17098240],"y":["Saudi Arabia","Democratic Republic of the Congo","Algeria","Kazakhstan","Argentina","India","Brazil","China","Canada","Russia"],"type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"margin":{"l":220},"title":{"text":"Top 10 Biggest Countries in the World by Land Area"},"xaxis":{"title":{"text":"Land Area in square kilometers"}},"plot_bgcolor":"rgba(0, 0, 0, 0)","paper_bgcolor":"rgba(0, 0, 0, 0)"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('217a0394-31c4-4140-92ce-ae7e76a1e83b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
fig = px.histogram(df, x="FertilityRate", marginal="box", nbins=20, hover_data=df[['Country']])

fig.update_traces(
    boxpoints='all',
    boxmean='sd',
    marker=dict(color='#ea4335'),
    selector=dict(type='box')
)

fig.update_traces(
    marker_color='#4285f4',
    selector=dict(type='histogram'))

fig.update_layout(
    title='Boxplot of Fertility Rate of Countries',
    xaxis_title="Fertility Rate",
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)

fig.show()
# Out:
# <div>                            <div id="f22d0517-1b75-4cbe-b3aa-316679db0823" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f22d0517-1b75-4cbe-b3aa-316679db0823")) {                    Plotly.newPlot(                        "f22d0517-1b75-4cbe-b3aa-316679db0823",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"FertilityRate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#4285f4","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[4.47,1.62,3.02,5.52,2.26,1.76,1.73,2.04,1.62,1.62,2.31,4.84,2.87,1.73,1.56,5.19,4.65,2.27,4.57,1.5,1.65,1.69,1.81,1.75,1.47,1.69,5.92,2.35,1.59,2.77,1.88,3.97,5.22,2.06,1.56,3.87,1.35,2.87,2.46,1.54,2.22,2.31,2.14,3.67,3.09,1.98,2.76,2.84,3.49,2.08,3.3,2.67,1.6,2.09,1.63,1.37,4.08,4.21,2.0,5.88,1.23,1.41,1.26,2.9,2.42,4.85,2.15,1.92,1.71,2.4,6.91,5.39,2.89,3.51,3.56,2.43,2.25,2.58,1.46,1.38,1.71,1.57,2.32,4.63,1.49,4.26,1.52,1.6,0.98,1.26,2.2,4.41,2.81,3.59,4.89,1.53,4.02,4.32,1.73,2.2,2.07,4.96,1.3,1.68,1.97,2.05,4.63],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[["Afghanistan"],["Albania"],["Algeria"],["Angola"],["Argentina"],["Armenia"],["Azerbaijan"],["Bangladesh"],["Barbados"],["Belgium"],["Belize"],["Benin"],["Botswana"],["Brazil"],["Bulgaria"],["Burkina Faso"],["Ivory Coast"],["Cape Verde"],["Cameroon"],["Canada"],["Chile"],["China"],["Colombia"],["Costa Rica"],["Croatia"],["Czech Republic"],["Democratic Republic of the Congo"],["Dominican Republic"],["Estonia"],["Fiji"],["France"],["Gabon"],["The Gambia"],["Georgia"],["Germany"],["Ghana"],["Greece"],["Guatemala"],["Honduras"],["Hungary"],["India"],["Indonesia"],["Iran"],["Iraq"],["Israel"],["Jamaica"],["Jordan"],["Kazakhstan"],["Kenya"],["Kuwait"],["Kyrgyzstan"],["Laos"],["Latvia"],["Lebanon"],["Lithuania"],["Luxembourg"],["Madagascar"],["Malawi"],["Malaysia"],["Mali"],["Malta"],["Mauritius"],["Moldova"],["Mongolia"],["Morocco"],["Mozambique"],["Myanmar"],["Nepal"],["New Zealand"],["Nicaragua"],["Niger"],["Nigeria"],["Oman"],["Pakistan"],["Papua New Guinea"],["Paraguay"],["Peru"],["Philippines"],["Poland"],["Portugal"],["Romania"],["Russia"],["Saudi Arabia"],["Senegal"],["Serbia"],["Sierra Leone"],["Slovakia"],["Slovenia"],["South Korea"],["Spain"],["Sri Lanka"],["Sudan"],["Syria"],["Tajikistan"],["Tanzania"],["Thailand"],["East Timor"],["Togo"],["Trinidad and Tobago"],["Tunisia"],["Turkey"],["Uganda"],["Ukraine"],["United Kingdom"],["Uruguay"],["Vietnam"],["Zambia"]],"hovertemplate":"FertilityRate=%{x}\u003cbr\u003eCountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#ea4335"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[4.47,1.62,3.02,5.52,2.26,1.76,1.73,2.04,1.62,1.62,2.31,4.84,2.87,1.73,1.56,5.19,4.65,2.27,4.57,1.5,1.65,1.69,1.81,1.75,1.47,1.69,5.92,2.35,1.59,2.77,1.88,3.97,5.22,2.06,1.56,3.87,1.35,2.87,2.46,1.54,2.22,2.31,2.14,3.67,3.09,1.98,2.76,2.84,3.49,2.08,3.3,2.67,1.6,2.09,1.63,1.37,4.08,4.21,2.0,5.88,1.23,1.41,1.26,2.9,2.42,4.85,2.15,1.92,1.71,2.4,6.91,5.39,2.89,3.51,3.56,2.43,2.25,2.58,1.46,1.38,1.71,1.57,2.32,4.63,1.49,4.26,1.52,1.6,0.98,1.26,2.2,4.41,2.81,3.59,4.89,1.53,4.02,4.32,1.73,2.2,2.07,4.96,1.3,1.68,1.97,2.05,4.63],"xaxis":"x2","yaxis":"y2","type":"box","boxmean":"sd","boxpoints":"all"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Fertility Rate"}},"yaxis":{"anchor":"x","domain":[0.0,0.8316],"title":{"text":"count"}},"xaxis2" ...
#
# var gd = document.getElementById('f22d0517-1b75-4cbe-b3aa-316679db0823');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# From [Britannica](https://www.britannica.com/topic/fertility-rate),
# > The single most important factor in population growth is the <b><mark>total fertility rate</mark></b> (TFR). If, on average, women give birth to <b><mark>2.1</mark></b> children and these children survive to the age of 15, any given woman will have replaced herself and her partner upon death. A TFR of 2.1 is known as the replacement rate. Generally speaking, when the TFR is greater than 2.1, the population in a given area will increase, and when it is less than 2.1, the population in a given area will eventually decrease, though it may take some time because factors such as age structure, emigration, or immigration must be considered.
#
# From the boxplot:
# - Median = $2.22$
# - Mean $ \pm $ standard deviation = $2.69\pm 1.31$
#
# Both the mean and median is well above 2.1 (the replacement rate). But can we conclude that this is an evidence that the human civilization is on the path to overpopulation?
# No. We could've draw that conclusion if the population in each country was the same, which isn't true. We need to calculate the average fertility of each person on Earth to draw this conclusion.
# So, we need to weigh the fertility rate of each country by their population size and then calculate the average of the weighed values to calculate the average fertility rate of each human on Earth.

# %%
weighed_values = (df['FertilityRate']*df['Population']).sum()
total_population = df['Population'].sum()
mean = weighed_values/total_population
print(mean)
# Out:
# 2.4374499265489247

# %% [markdown]
# And we've got our answer!!
# The average fertility rate of each human on Earth is $2.437$, which is higher than the replacement rate ($2.1$)
# Therefore, this is an evidence that we are on the road to population growth.

# %% [markdown]
# We can use the data about each country's fertility rate to predict which countries will experience a population growth in the future.
# Let's subtract $2.1$ from fertility rate and call it 'population growth indicator'.
# If this value is more than zero, the country will experience a population growth, otherwise if this value is less than zero the country's population will decrease.

# %%
df['population_growth_indicator'] = df['FertilityRate'] - 2.1
df['population_growth_indicator'] = df['population_growth_indicator'].apply(lambda x:float('{:.3g}'.format(x)))

# Create the bar chart
fig = px.bar(df, x='population_growth_indicator', y='Country', text='population_growth_indicator', orientation='h')

# Set different colors for bars with negative and positive values
fig.update_traces(marker_color=['#ea4335' if val < 0 else '#4285f4' for val in df['population_growth_indicator']],
                  textposition='outside')

# Uniform text settings
fig.update_layout(
    uniformtext_minsize=8,
    uniformtext_mode='hide',
    height=2600,
    title="Population Growth Indicator for Countries",
    template='gridon',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
    margin=dict(l=220)  # Adjust the left margin to make room for long labels
)

# Show the figure
fig.show()
# Out:
# <div>                            <div id="f2f31c90-04af-48de-a819-e43366dd553b" class="plotly-graph-div" style="height:2600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2f31c90-04af-48de-a819-e43366dd553b")) {                    Plotly.newPlot(                        "f2f31c90-04af-48de-a819-e43366dd553b",                        [{"alignmentgroup":"True","hovertemplate":"population_growth_indicator=%{text}\u003cbr\u003eCountry=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["#4285f4","#ea4335","#4285f4","#4285f4","#4285f4","#ea4335","#ea4335","#ea4335","#ea4335","#ea4335","#4285f4","#4285f4","#4285f4","#ea4335","#ea4335","#4285f4","#4285f4","#4285f4","#4285f4","#ea4335","#ea4335","#ea4335","#ea4335","#ea4335","#ea4335","#ea4335","#4285f4","#4285f4","#ea4335","#4285f4","#ea4335","#4285f4","#4285f4","#ea4335","#ea4335","#4285f4","#ea4335","#4285f4","#4285f4","#ea4335","#4285f4","#4285f4","#4285f4","#4285f4","#4285f4","#ea4335","#4285f4","#4285f4","#4285f4","#ea4335","#4285f4","#4285f4","#ea4335","#ea4335","#ea4335","#ea4335","#4285f4","#4285f4","#ea4335","#4285f4","#ea4335","#ea4335","#ea4335","#4285f4","#4285f4","#4285f4","#4285f4","#ea4335","#ea4335","#4285f4","#4285f4","#4285f4","#4285f4","#4285f4","#4285f4","#4285f4","#4285f4","#4285f4","#ea4335","#ea4335","#ea4335","#ea4335","#4285f4","#4285f4","#ea4335","#4285f4","#ea4335","#ea4335","#ea4335","#ea4335","#4285f4","#4285f4","#4285f4","#4285f4","#4285f4","#ea4335","#4285f4","#4285f4","#ea4335","#4285f4","#ea4335","#4285f4","#ea4335","#ea4335","#ea4335","#ea4335","#4285f4"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[2.37,-0.48,0.92,3.42,0.16,-0.34,-0.37,-0.06,-0.48,-0.48,0.21,2.74,0.77,-0.37,-0.54,3.09,2.55,0.17,2.47,-0.6,-0.45,-0.41,-0.29,-0.35,-0.63,-0.41,3.82,0.25,-0.51,0.67,-0.22,1.87,3.12,-0.04,-0.54,1.77,-0.75,0.77,0.36,-0.56,0.12,0.21,0.04,1.57,0.99,-0.12,0.66,0.74,1.39,-0.02,1.2,0.57,-0.5,-0.01,-0.47,-0.73,1.98,2.11,-0.1,3.78,-0.87,-0.69,-0.84,0.8,0.32,2.75,0.05,-0.18,-0.39,0.3,4.81,3.29,0.79,1.41,1.46,0.33,0.15,0.48,-0.64,-0.72,-0.39,-0.53,0.22,2.53,-0.61,2.16,-0.58,-0.5,-1.12,-0.84,0.1,2.31,0.71,1.49,2.79,-0.57,1.92,2.22,-0.37,0.1,-0.03,2.86,-0.8,-0.42,-0.13,-0.05,2.53],"textposition":"outside","x":[2.37,-0.48,0.92,3.42,0.16,-0.34,-0.37,-0.06,-0.48,-0.48,0.21,2.74,0.77,-0.37,-0.54,3.09,2.55,0.17,2.47,-0.6,-0.45,-0.41,-0.29,-0.35,-0.63,-0.41,3.82,0.25,-0.51,0.67,-0.22,1.87,3.12,-0.04,-0.54,1.77,-0.75,0.77,0.36,-0.56,0.12,0.21,0.04,1.57,0.99,-0.12,0.66,0.74,1.39,-0.02,1.2,0.57,-0.5,-0.01,-0.47,-0.73,1.98,2.11,-0.1,3.78,-0.87,-0.69,-0.84,0.8,0.32,2.75,0.05,-0.18,-0.39,0.3,4.81,3.29,0.79,1.41,1.46,0.33,0.15,0.48,-0.64,-0.72,-0.39,-0.53,0.22,2.53,-0.61,2.16,-0.58,-0.5,-1.12,-0.84,0.1,2.31,0.71,1.49,2.79,-0.57,1.92,2.22,-0.37,0.1,-0.03,2.86,-0.8,-0.42,-0.13,-0.05,2.53],"xaxis":"x","y":["Afghanistan","Albania","Algeria","Angola","Argentina","Armenia","Azerbaijan","Bangladesh","Barbados","Belgium","Belize","Benin","Botswana","Brazil","Bulgaria","Burkina Faso","Ivory Coast","Cape Verde","Cameroon","Canada","Chile","China","Colombia","Costa Rica","Croatia","Czech Republic","Democratic Republic of the Congo","Dominican Republic","Estonia","Fiji","France","Gabon","The Gambia","Georgia","Germany","Ghana","Greece","Guatemala","Honduras","Hungary","India","Indonesia","Iran","Iraq","Israel","Jamaica","Jordan","Kazakhstan","Kenya","Kuwait","Kyrgyzstan","Laos","Latvia","Lebanon","Lithuania","Luxembourg","Madagascar","Malawi","Malaysia","Mali","Malta","Mauritius","Moldova","Mongolia","Morocco","Mozambique","Myanmar","Nepal","New Zealand","Nicaragua","Niger","Nigeria","Oman","Pakistan","Papua New Guinea","Paraguay","Peru","Philippines","Poland","Portugal","Romania","Russia","Saudi Arabia","Senegal","Serbi ...
#
# var gd = document.getElementById('f2f31c90-04af-48de-a819-e43366dd553b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# You can use this graph to predict which countries will experience a population growth in the next few decades, if the fertility rate remains approximately the same.
# You cannot, however, use this graph to predict which countries will face a <b><mark>overpopulation crisis</mark></b> or an <b><mark>underpopulation crisis</mark></b> because there are other factors to consider. For example, a country might have a high fertility rate, but that doesn't mean they will experience an overpopulation crisis because they might have a high number of old people who will pass away soon or they might have a large land area to cover a large number of people. And this is just one example where land area or the distribution of age of the population is a factor to consider. There can be much, much more factors to consider when making such kind of predictions.

# %% [markdown]
# *That's it for now...
# Yes I know I haven't done any analysis on some variables, for example:*
# - *Agricultural Land*
# - *Armed Forces Size*
# - *Gasoline Price*
# - *Tax Revenue*
# etc...
#
# *I'll do it later when I get some time.
# If you're reading this, and it's been a while since I've published this notebook, it is possible that I forgot to update it. Maybe you can remind me through a comment?
# Thanks for reading by the way. Hope you enjoyed it!*
